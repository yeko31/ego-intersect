# %% [markdown]
# Mb Syn

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, Dataset
from torchvision import transforms, models
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import numpy as np
from PIL import Image
from copy import deepcopy
import matplotlib.pyplot as plt

# -------------------- Dataset --------------------
class MultiLabelDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        for subfolder in os.listdir(root_dir):
            sub_path = os.path.join(root_dir, subfolder)
            if not os.path.isdir(sub_path):
                continue
            label_vector = [int(x) for x in subfolder.split('_')]
            for fname in os.listdir(sub_path):
                if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                    self.images.append(os.path.join(sub_path, fname))
                    self.labels.append(label_vector)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = torch.tensor(self.labels[idx], dtype=torch.float)

        img = Image.open(img_path).convert("L")  # grayscale
        if self.transform:
            img = self.transform(img)

        # expand grayscale → 3 channels
        img = img.repeat(3, 1, 1)
        return img, label

# -------------------- Transforms --------------------
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

dataset = MultiLabelDataset(
    "", #Include dataset path 
    transform=transform
)

# -------------------- Model Loader --------------------
def get_model(pretrained="synthetic"):
    if pretrained == "imagenet":
        model = models.mobilenet_v2(weights="IMAGENET1K_V1")

    elif pretrained == "synthetic":
        model = models.mobilenet_v2(pretrained=False)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, 3)
        ckpt_path = "" #Include check path 
        state_dict = torch.load(ckpt_path, map_location="cpu")
        model.load_state_dict(state_dict)

    # Unfreeze all layers — full fine-tuning
    for param in model.parameters():
        param.requires_grad = True

    # Replace classifier for current task
    in_features = model.classifier[1].in_features
    model.classifier[1] = nn.Linear(in_features, 3)

    return model

# -------------------- KFold Cross-validation --------------------
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

results = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

best_acc = 0.0
best_model_wts = None
best_fold_history = None

# --- Early stopping config ---
patience = 3
min_delta = 1e-4

for fold, (train_ids, val_ids) in enumerate(kf.split(np.arange(len(dataset)))):
    print(f"\nFOLD {fold+1}/{k_folds}")
    print("-"*20)

    train_sub = Subset(dataset, train_ids)
    val_sub = Subset(dataset, val_ids)
    
    train_loader = DataLoader(train_sub, batch_size=16, shuffle=True)
    val_loader = DataLoader(val_sub, batch_size=16)
   
    model = get_model(pretrained="synthetic")  # or "imagenet"
    model.to(device)

    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-4)  # lower LR for full fine-tuning

    best_val_acc = 0.0
    best_fold_wts = None
    epochs_no_improve = 0
    num_epochs = 30

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        y_true_train, y_pred_train = [], []
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            preds = (torch.sigmoid(out) > 0.5).int()
            y_true_train.extend(y.cpu().numpy())
            y_pred_train.extend(preds.cpu().numpy())

        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(y_true_train, y_pred_train)

        # --- Validation ---
        model.eval()
        y_true, y_pred = [], []
        val_loss_total = 0.0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                val_loss_total += loss.item()
                preds = (torch.sigmoid(out) > 0.5).int()
                y_true.extend(y.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_acc = accuracy_score(y_true, y_pred)

        print(f"Epoch {epoch+1}: "
              f"Train Loss {train_loss:.4f}, Train Acc {train_acc:.4f}, "
              f"Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        # --- Early stopping check ---
        if val_acc - best_val_acc > min_delta:
            best_val_acc = val_acc
            best_fold_wts = deepcopy(model.state_dict())
            best_fold_history = deepcopy(history)
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    results.append(best_val_acc)
    print(f"Fold {fold+1} Best Val Accuracy: {best_val_acc:.4f}")

    if best_val_acc > best_acc:
        best_acc = best_val_acc
        best_model_wts = deepcopy(best_fold_wts)

print(f"\nMean Accuracy across {k_folds} folds: {np.mean(results):.4f}")
print(f"Best Accuracy observed: {best_acc:.4f}")

# -------------------- Save Best Model --------------------
save_path = "" ##Include save path 
save_path_old = " " #Include save old path 
torch.save(best_model_wts, save_path)
torch.save(best_model_wts, save_path_old, _use_new_zipfile_serialization=False)
print(f"Best model saved to {save_path}")

# -------------------- Plot Best Fold History --------------------
plt.figure(figsize=(10,6))
plt.plot(best_fold_history["train_loss"], label="Train Loss")
plt.plot(best_fold_history["val_loss"], label="Val Loss")
plt.plot(best_fold_history["train_acc"], label="Train Acc")
plt.plot(best_fold_history["val_acc"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Metric")
plt.title("Training/Validation Metrics (Best Fold) - Full Fine-tuning")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# FOLD 1/5
# --------------------
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1: Train Loss 0.3786, Train Acc 0.6230, Val Loss 0.1513, Val Acc 0.8690
# Epoch 2: Train Loss 0.1382, Train Acc 0.8848, Val Loss 0.0646, Val Acc 0.9529
# Epoch 3: Train Loss 0.0840, Train Acc 0.9322, Val Loss 0.0423, Val Acc 0.9720
# Epoch 4: Train Loss 0.0572, Train Acc 0.9555, Val Loss 0.0342, Val Acc 0.9746
# Epoch 5: Train Loss 0.0470, Train Acc 0.9618, Val Loss 0.0124, Val Acc 0.9962
# Epoch 6: Train Loss 0.0375, Train Acc 0.9704, Val Loss 0.0139, Val Acc 0.9860
# Epoch 7: Train Loss 0.0289, Train Acc 0.9784, Val Loss 0.0133, Val Acc 0.9962
# Epoch 8: Train Loss 0.0275, Train Acc 0.9777, Val Loss 0.0053, Val Acc 0.9975
# Epoch 9: Train Loss 0.0254, Train Acc 0.9809, Val Loss 0.0092, Val Acc 0.9911
# Epoch 10: Train Loss 0.0168, Train Acc 0.9892, Val Loss 0.0058, Val Acc 0.9962
# Epoch 11: Train Loss 0.0142, Train Acc 0.9911, Val Loss 0.0025, Val Acc 1.0000
# Epoch 12: Train Loss 0.0108, Train Acc 0.9936, Val Loss 0.0025, Val Acc 1.0000
# Epoch 13: Train Loss 0.0113, Train Acc 0.9927, Val Loss 0.0018, Val Acc 1.0000
# Epoch 14: Train Loss 0.0080, Train Acc 0.9943, Val Loss 0.0023, Val Acc 1.0000
# Early stopping at epoch 14
# Fold 1 Best Val Accuracy: 1.0000
#
# FOLD 2/5
# --------------------
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1: Train Loss 0.4060, Train Acc 0.5838, Val Loss 0.1797, Val Acc 0.8575
# Epoch 2: Train Loss 0.1504, Train Acc 0.8734, Val Loss 0.0639, Val Acc 0.9656
# Epoch 3: Train Loss 0.0836, Train Acc 0.9319, Val Loss 0.0355, Val Acc 0.9835
# Epoch 4: Train Loss 0.0620, Train Acc 0.9494, Val Loss 0.0234, Val Acc 0.9860
# Epoch 5: Train Loss 0.0405, Train Acc 0.9701, Val Loss 0.0196, Val Acc 0.9885
# Epoch 6: Train Loss 0.0333, Train Acc 0.9752, Val Loss 0.0152, Val Acc 0.9898
# Epoch 7: Train Loss 0.0276, Train Acc 0.9784, Val Loss 0.0067, Val Acc 0.9975
# Epoch 8: Train Loss 0.0234, Train Acc 0.9825, Val Loss 0.0050, Val Acc 0.9987
# Epoch 9: Train Loss 0.0184, Train Acc 0.9876, Val Loss 0.0103, Val Acc 0.9962
# Epoch 10: Train Loss 0.0172, Train Acc 0.9901, Val Loss 0.0054, Val Acc 0.9962
# Epoch 11: Train Loss 0.0152, Train Acc 0.9895, Val Loss 0.0021, Val Acc 1.0000
# Epoch 12: Train Loss 0.0135, Train Acc 0.9917, Val Loss 0.0026, Val Acc 1.0000
# Epoch 13: Train Loss 0.0219, Train Acc 0.9793, Val Loss 0.0019, Val Acc 1.0000
# Epoch 14: Train Loss 0.0178, Train Acc 0.9847, Val Loss 0.0018, Val Acc 1.0000
# Early stopping at epoch 14
# Fold 2 Best Val Accuracy: 1.0000
#
# FOLD 3/5
# --------------------
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1: Train Loss 0.3948, Train Acc 0.6058, Val Loss 0.1856, Val Acc 0.8448
# Epoch 2: Train Loss 0.1542, Train Acc 0.8664, Val Loss 0.0787, Val Acc 0.9402
# Epoch 3: Train Loss 0.0866, Train Acc 0.9319, Val Loss 0.0411, Val Acc 0.9733
# Epoch 4: Train Loss 0.0554, Train Acc 0.9561, Val Loss 0.0224, Val Acc 0.9860
# Epoch 5: Train Loss 0.0423, Train Acc 0.9717, Val Loss 0.0133, Val Acc 0.9936
# Epoch 6: Train Loss 0.0391, Train Acc 0.9714, Val Loss 0.0201, Val Acc 0.9873
# Epoch 7: Train Loss 0.0293, Train Acc 0.9784, Val Loss 0.0090, Val Acc 0.9987
# Epoch 8: Train Loss 0.0237, Train Acc 0.9831, Val Loss 0.0157, Val Acc 0.9911
# Epoch 9: Train Loss 0.0194, Train Acc 0.9870, Val Loss 0.0059, Val Acc 0.9962
# Epoch 10: Train Loss 0.0193, Train Acc 0.9841, Val Loss 0.0075, Val Acc 0.9987
# Early stopping at epoch 10
# Fold 3 Best Val Accuracy: 0.9987
#
# FOLD 4/5
# --------------------
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1: Train Loss 0.3943, Train Acc 0.6001, Val Loss 0.1557, Val Acc 0.8779
# Epoch 2: Train Loss 0.1489, Train Acc 0.8775, Val Loss 0.1562, Val Acc 0.8550
# Epoch 3: Train Loss 0.0792, Train Acc 0.9364, Val Loss 0.0385, Val Acc 0.9746
# Epoch 4: Train Loss 0.0586, Train Acc 0.9555, Val Loss 0.0160, Val Acc 0.9924
# Epoch 5: Train Loss 0.0416, Train Acc 0.9682, Val Loss 0.0204, Val Acc 0.9847
# Epoch 6: Train Loss 0.0351, Train Acc 0.9774, Val Loss 0.0142, Val Acc 0.9885
# Epoch 7: Train Loss 0.0332, Train Acc 0.9787, Val Loss 0.0143, Val Acc 0.9873
# Early stopping at epoch 7
# Fold 4 Best Val Accuracy: 0.9924
#
# FOLD 5/5
# --------------------
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/intellisense08/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1: Train Loss 0.3836, Train Acc 0.6085, Val Loss 0.2175, Val Acc 0.7847
# Epoch 2: Train Loss 0.1434, Train Acc 0.8779, Val Loss 0.0657, Val Acc 0.9452
# Epoch 3: Train Loss 0.0817, Train Acc 0.9313, Val Loss 0.0294, Val Acc 0.9809
# Epoch 4: Train Loss 0.0493, Train Acc 0.9609, Val Loss 0.0271, Val Acc 0.9860
# Epoch 5: Train Loss 0.0427, Train Acc 0.9679, Val Loss 0.0137, Val Acc 0.9924
# Epoch 6: Train Loss 0.0356, Train Acc 0.9742, Val Loss 0.0097, Val Acc 0.9924
# Epoch 7: Train Loss 0.0332, Train Acc 0.9771, Val Loss 0.0053, Val Acc 0.9987
# Epoch 8: Train Loss 0.0219, Train Acc 0.9860, Val Loss 0.0074, Val Acc 0.9949
# Epoch 9: Train Loss 0.0233, Train Acc 0.9851, Val Loss 0.0041, Val Acc 0.9987
# Epoch 10: Train Loss 0.0155, Train Acc 0.9901, Val Loss 0.0038, Val Acc 0.9975
# Early stopping at epoch 10
# Fold 5 Best Val Accuracy: 0.9987
#
# Mean Accuracy across 5 folds: 0.9980
# Best Accuracy observed: 1.0000
# Best model saved to /home/intellisense08/Yehan/project_dir/Real_World_data/trained_models/Lib_keells_Aug_left_right/all_layers/syn/mobilenetv2_synbest_fullfinetune.pth

# %%
import re
import matplotlib.pyplot as plt

# --- Path to your log file ---
log_path = ""

# --- Read file ---
with open(log_path, "r") as f:
    lines = f.readlines()

# --- Prepare storage ---
epochs = []
train_loss, val_loss = [], []
train_acc, val_acc = [], []

# --- Parse each line ---
for line in lines:
    match = re.search(
        r"Epoch (\d+): Train Loss ([\d.]+), Train Acc ([\d.]+), Val Loss ([\d.]+), Val Acc ([\d.]+)",
        line.strip()
    )
    if match:
        e, tl, ta, vl, va = match.groups()
        epochs.append(int(e))
        train_loss.append(float(tl))
        train_acc.append(float(ta))
        val_loss.append(float(vl))
        val_acc.append(float(va))

# --- Plot ---
plt.figure(figsize=(10,6))
plt.plot(epochs, train_loss, label="Train Loss", linestyle="--", marker="o")
plt.plot(epochs, val_loss, label="Val Loss", linestyle="--", marker="s")
plt.plot(epochs, train_acc, label="Train Acc", linestyle="-", marker="o")
plt.plot(epochs, val_acc, label="Val Acc", linestyle="-", marker="s")

plt.title("Training and Validation Metrics per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
