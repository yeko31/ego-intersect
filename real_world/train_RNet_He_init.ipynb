# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, Dataset
from torchvision import transforms, models
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import numpy as np
from PIL import Image
from copy import deepcopy
import matplotlib.pyplot as plt

# -------------------- Dataset --------------------
class MultiLabelDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        for subfolder in os.listdir(root_dir):
            sub_path = os.path.join(root_dir, subfolder)
            if not os.path.isdir(sub_path):
                continue
            label_vector = [int(x) for x in subfolder.split('_')]
            for fname in os.listdir(sub_path):
                if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                    self.images.append(os.path.join(sub_path, fname))
                    self.labels.append(label_vector)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = torch.tensor(self.labels[idx], dtype=torch.float)

        img = Image.open(img_path).convert("L")  # grayscale
        if self.transform:
            img = self.transform(img)

        # expand grayscale → 3 channels
        img = img.repeat(3, 1, 1)
        return img, label


# -------------------- Transforms --------------------
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

dataset = MultiLabelDataset(
    "", #Include data path 
    transform=transform
)


# -------------------- He Initialization Function --------------------
def init_weights(m):
    """Apply Kaiming (He) initialization to Conv and Linear layers."""
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.constant_(m.weight, 1)
        nn.init.constant_(m.bias, 0)


# -------------------- Model Loader --------------------
def get_model():
    # Load ResNet50 architecture, no pretrained weights
    model = models.resnet50(weights=None)

    # Replace fully connected layer for 3 output nodes (multi-label)
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, 3)

    # Apply He initialization to all layers
    model.apply(init_weights)

    return model


# -------------------- KFold Cross-validation --------------------
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

results = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

best_acc = 0.0
best_model_wts = None
best_fold_history = None

# Early stopping parameters
patience = 3
min_delta = 1e-4

for fold, (train_ids, val_ids) in enumerate(kf.split(np.arange(len(dataset)))):
    print(f"\nFOLD {fold+1}/{k_folds}")
    print("-" * 20)

    train_sub = Subset(dataset, train_ids)
    val_sub = Subset(dataset, val_ids)

    train_loader = DataLoader(train_sub, batch_size=16, shuffle=True)
    val_loader = DataLoader(val_sub, batch_size=16)

    model = get_model().to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)

    best_val_acc = 0.0
    best_fold_wts = None
    epochs_no_improve = 0
    num_epochs = 30

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    for epoch in range(num_epochs):
        # ---- Training ----
        model.train()
        running_loss = 0.0
        y_true_train, y_pred_train = [], []
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            preds = (torch.sigmoid(out) > 0.5).int()
            y_true_train.extend(y.cpu().numpy())
            y_pred_train.extend(preds.cpu().numpy())

        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(y_true_train, y_pred_train)

        # ---- Validation ----
        model.eval()
        y_true, y_pred = [], []
        val_loss_total = 0.0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                val_loss_total += loss.item()
                preds = (torch.sigmoid(out) > 0.5).int()
                y_true.extend(y.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_acc = accuracy_score(y_true, y_pred)

        print(f"Epoch {epoch+1}: "
              f"Train Loss {train_loss:.4f}, Train Acc {train_acc:.4f}, "
              f"Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        # ---- Early stopping ----
        if val_acc - best_val_acc > min_delta:
            best_val_acc = val_acc
            best_fold_wts = deepcopy(model.state_dict())
            best_fold_history = deepcopy(history)
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    results.append(best_val_acc)
    print(f"Fold {fold+1} Best Val Accuracy: {best_val_acc:.4f}")

    if best_val_acc > best_acc:
        best_acc = best_val_acc
        best_model_wts = deepcopy(best_fold_wts)

print(f"\nMean Accuracy across {k_folds} folds: {np.mean(results):.4f}")
print(f"Best Accuracy observed: {best_acc:.4f}")

# -------------------- Save Best Model --------------------
save_path = "" #Include save path 
torch.save(best_model_wts, save_path)

# -------------------- Plot final Fold History --------------------
plt.figure(figsize=(10, 6))
plt.plot(best_fold_history["train_loss"], label="Train Loss")
plt.plot(best_fold_history["val_loss"], label="Val Loss")
plt.plot(best_fold_history["train_acc"], label="Train Acc")
plt.plot(best_fold_history["val_acc"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Metric")
plt.title("Training/Validation Metrics (Best Fold) - ResNet50 (He Initialization)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# FOLD 1/5
# --------------------
# Epoch 1: Train Loss 2.6574, Train Acc 0.3815, Val Loss 0.7380, Val Acc 0.4847
# Epoch 2: Train Loss 0.3683, Train Acc 0.6879, Val Loss 2.6739, Val Acc 0.4466
# Epoch 3: Train Loss 0.2475, Train Acc 0.8062, Val Loss 0.5013, Val Acc 0.6692
# Epoch 4: Train Loss 0.1941, Train Acc 0.8521, Val Loss 0.1529, Val Acc 0.8397
# Epoch 5: Train Loss 0.0945, Train Acc 0.9128, Val Loss 0.3362, Val Acc 0.8919
# Epoch 6: Train Loss 0.0706, Train Acc 0.9319, Val Loss 0.0976, Val Acc 0.9580
# Epoch 7: Train Loss 0.1142, Train Acc 0.9109, Val Loss 0.1338, Val Acc 0.9097
# Epoch 8: Train Loss 0.0875, Train Acc 0.9249, Val Loss 0.1673, Val Acc 0.9351
# Epoch 9: Train Loss 0.0577, Train Acc 0.9497, Val Loss 0.0295, Val Acc 0.9733
# Epoch 10: Train Loss 0.0624, Train Acc 0.9513, Val Loss 0.0346, Val Acc 0.9707
# Epoch 11: Train Loss 0.1854, Train Acc 0.8944, Val Loss 4.5202, Val Acc 0.3473
# Epoch 12: Train Loss 0.2367, Train Acc 0.8603, Val Loss 0.1289, Val Acc 0.8944
# Early stopping at epoch 12
# Fold 1 Best Val Accuracy: 0.9733
#
# FOLD 2/5
# --------------------
# Epoch 1: Train Loss 3.1887, Train Acc 0.3904, Val Loss 2.2985, Val Acc 0.4351
# Epoch 2: Train Loss 0.3185, Train Acc 0.7270, Val Loss 0.2279, Val Acc 0.8562
# Epoch 3: Train Loss 0.2231, Train Acc 0.8145, Val Loss 0.3888, Val Acc 0.8677
# Epoch 4: Train Loss 0.1629, Train Acc 0.8737, Val Loss 0.2718, Val Acc 0.8372
# Epoch 5: Train Loss 0.0952, Train Acc 0.9176, Val Loss 0.3021, Val Acc 0.9224
# Epoch 6: Train Loss 0.1101, Train Acc 0.9141, Val Loss 0.1202, Val Acc 0.9275
# Epoch 7: Train Loss 0.1194, Train Acc 0.9255, Val Loss 0.3263, Val Acc 0.8206
# Epoch 8: Train Loss 0.1059, Train Acc 0.9211, Val Loss 0.2283, Val Acc 0.9364
# Epoch 9: Train Loss 0.0464, Train Acc 0.9593, Val Loss 0.0098, Val Acc 0.9924
# Epoch 10: Train Loss 0.0688, Train Acc 0.9459, Val Loss 0.1396, Val Acc 0.8957
# Epoch 11: Train Loss 0.0858, Train Acc 0.9443, Val Loss 0.0753, Val Acc 0.9377
# Epoch 12: Train Loss 0.0492, Train Acc 0.9647, Val Loss 0.0748, Val Acc 0.9720
# Early stopping at epoch 12
# Fold 2 Best Val Accuracy: 0.9924
#
# FOLD 3/5
# --------------------
# Epoch 1: Train Loss 3.0816, Train Acc 0.3799, Val Loss 0.8005, Val Acc 0.4148
# Epoch 2: Train Loss 0.4719, Train Acc 0.6335, Val Loss 0.6722, Val Acc 0.6603
# Epoch 3: Train Loss 0.3043, Train Acc 0.7821, Val Loss 1.4512, Val Acc 0.7443
# Epoch 4: Train Loss 0.1588, Train Acc 0.8616, Val Loss 0.5938, Val Acc 0.7545
# Epoch 5: Train Loss 0.1565, Train Acc 0.8785, Val Loss 0.3174, Val Acc 0.8868
# Epoch 6: Train Loss 0.0896, Train Acc 0.9262, Val Loss 3.0759, Val Acc 0.8931
# Epoch 7: Train Loss 0.0883, Train Acc 0.9399, Val Loss 0.1890, Val Acc 0.9567
# Epoch 8: Train Loss 0.0429, Train Acc 0.9640, Val Loss 1.6539, Val Acc 0.9109
# Epoch 9: Train Loss 0.1201, Train Acc 0.9109, Val Loss 0.1029, Val Acc 0.9580
# Epoch 10: Train Loss 0.0785, Train Acc 0.9389, Val Loss 0.6934, Val Acc 0.9122
# Epoch 11: Train Loss 0.0578, Train Acc 0.9574, Val Loss 5.7960, Val Acc 0.4478
# Epoch 12: Train Loss 0.0904, Train Acc 0.9335, Val Loss 1.0862, Val Acc 0.7252
# Early stopping at epoch 12
# Fold 3 Best Val Accuracy: 0.9580
#
# FOLD 4/5
# --------------------
# Epoch 1: Train Loss 3.1046, Train Acc 0.3713, Val Loss 2.2392, Val Acc 0.2417
# Epoch 2: Train Loss 0.4573, Train Acc 0.6573, Val Loss 1.3487, Val Acc 0.3957
# Epoch 3: Train Loss 0.2552, Train Acc 0.7964, Val Loss 0.3836, Val Acc 0.7697
# Epoch 4: Train Loss 0.1594, Train Acc 0.8692, Val Loss 0.3146, Val Acc 0.8969
# Epoch 5: Train Loss 0.1418, Train Acc 0.8928, Val Loss 0.4547, Val Acc 0.8740
# Epoch 6: Train Loss 0.1281, Train Acc 0.9058, Val Loss 0.6870, Val Acc 0.8817
# Epoch 7: Train Loss 0.0999, Train Acc 0.9236, Val Loss 0.1877, Val Acc 0.9148
# Epoch 8: Train Loss 0.1208, Train Acc 0.9195, Val Loss 0.8279, Val Acc 0.7252
# Epoch 9: Train Loss 0.0788, Train Acc 0.9376, Val Loss 0.0414, Val Acc 0.9669
# Epoch 10: Train Loss 0.0501, Train Acc 0.9605, Val Loss 0.1111, Val Acc 0.9224
# Epoch 11: Train Loss 0.0564, Train Acc 0.9583, Val Loss 1.8872, Val Acc 0.7379
# Epoch 12: Train Loss 0.1502, Train Acc 0.9135, Val Loss 19.8365, Val Acc 0.3893
# Early stopping at epoch 12
# Fold 4 Best Val Accuracy: 0.9669
#
# FOLD 5/5
# --------------------
# Epoch 1: Train Loss 2.7078, Train Acc 0.3998, Val Loss 0.9921, Val Acc 0.4344
# Epoch 2: Train Loss 0.3957, Train Acc 0.6810, Val Loss 0.2772, Val Acc 0.7771
# Epoch 3: Train Loss 0.2349, Train Acc 0.7913, Val Loss 0.2581, Val Acc 0.7911
# Epoch 4: Train Loss 0.1970, Train Acc 0.8492, Val Loss 2.4264, Val Acc 0.5656
# Epoch 5: Train Loss 0.1184, Train Acc 0.9078, Val Loss 0.0243, Val Acc 0.9745
# Epoch 6: Train Loss 0.1055, Train Acc 0.9160, Val Loss 4.6931, Val Acc 0.3682
# Epoch 7: Train Loss 0.1166, Train Acc 0.9081, Val Loss 0.0529, Val Acc 0.9465
# Epoch 8: Train Loss 0.0800, Train Acc 0.9402, Val Loss 0.0895, Val Acc 0.9299
# Early stopping at epoch 8
# Fold 5 Best Val Accuracy: 0.9745
#
# Mean Accuracy across 5 folds: 0.9730
# Best Accuracy observed: 0.9924

# %% [markdown]
# fan_in

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, Dataset
from torchvision import transforms, models
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import numpy as np
from PIL import Image
from copy import deepcopy
import matplotlib.pyplot as plt

# -------------------- Dataset --------------------
class MultiLabelDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        for subfolder in os.listdir(root_dir):
            sub_path = os.path.join(root_dir, subfolder)
            if not os.path.isdir(sub_path):
                continue
            label_vector = [int(x) for x in subfolder.split('_')]
            for fname in os.listdir(sub_path):
                if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                    self.images.append(os.path.join(sub_path, fname))
                    self.labels.append(label_vector)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = torch.tensor(self.labels[idx], dtype=torch.float)

        img = Image.open(img_path).convert("L")  # grayscale
        if self.transform:
            img = self.transform(img)

        # expand grayscale → 3 channels
        img = img.repeat(3, 1, 1)
        return img, label


# -------------------- Transforms --------------------
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

dataset = MultiLabelDataset(
    "", #Include data path 
    transform=transform
)


# -------------------- He Initialization Function --------------------
def init_weights(m):
    """Apply Kaiming (He) initialization to Conv and Linear layers."""
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.constant_(m.weight, 1)
        nn.init.constant_(m.bias, 0)


# -------------------- Model Loader --------------------
def get_model():
    # Load ResNet50 architecture, no pretrained weights
    model = models.resnet50(weights=None)

    # Replace fully connected layer for 3 output nodes (multi-label)
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, 3)

    # Apply He initialization to all layers
    model.apply(init_weights)

    return model


# -------------------- KFold Cross-validation --------------------
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

results = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

best_acc = 0.0
best_model_wts = None
best_fold_history = None

# Early stopping parameters
patience = 3
min_delta = 1e-4

for fold, (train_ids, val_ids) in enumerate(kf.split(np.arange(len(dataset)))):
    print(f"\nFOLD {fold+1}/{k_folds}")
    print("-" * 20)

    train_sub = Subset(dataset, train_ids)
    val_sub = Subset(dataset, val_ids)

    train_loader = DataLoader(train_sub, batch_size=16, shuffle=True)
    val_loader = DataLoader(val_sub, batch_size=16)

    model = get_model().to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)

    best_val_acc = 0.0
    best_fold_wts = None
    epochs_no_improve = 0
    num_epochs = 30

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    for epoch in range(num_epochs):
        # ---- Training ----
        model.train()
        running_loss = 0.0
        y_true_train, y_pred_train = [], []
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            preds = (torch.sigmoid(out) > 0.5).int()
            y_true_train.extend(y.cpu().numpy())
            y_pred_train.extend(preds.cpu().numpy())

        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(y_true_train, y_pred_train)

        # ---- Validation ----
        model.eval()
        y_true, y_pred = [], []
        val_loss_total = 0.0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                val_loss_total += loss.item()
                preds = (torch.sigmoid(out) > 0.5).int()
                y_true.extend(y.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_acc = accuracy_score(y_true, y_pred)

        print(f"Epoch {epoch+1}: "
              f"Train Loss {train_loss:.4f}, Train Acc {train_acc:.4f}, "
              f"Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        # ---- Early stopping ----
        if val_acc - best_val_acc > min_delta:
            best_val_acc = val_acc
            best_fold_wts = deepcopy(model.state_dict())
            best_fold_history = deepcopy(history)
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    results.append(best_val_acc)
    print(f"Fold {fold+1} Best Val Accuracy: {best_val_acc:.4f}")

    if best_val_acc > best_acc:
        best_acc = best_val_acc
        best_model_wts = deepcopy(best_fold_wts)

print(f"\nMean Accuracy across {k_folds} folds: {np.mean(results):.4f}")
print(f"Best Accuracy observed: {best_acc:.4f}")

# -------------------- Save Best Model --------------------
save_path = "" #Include save path 
torch.save(best_model_wts, save_path)

# -------------------- Plot final Fold History --------------------
plt.figure(figsize=(10, 6))
plt.plot(best_fold_history["train_loss"], label="Train Loss")
plt.plot(best_fold_history["val_loss"], label="Val Loss")
plt.plot(best_fold_history["train_acc"], label="Train Acc")
plt.plot(best_fold_history["val_acc"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Metric")
plt.title("Training/Validation Metrics (Best Fold) - ResNet50 (He Initialization_fan_in)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# FOLD 1/5
# --------------------
# Epoch 1: Train Loss 0.5336, Train Acc 0.4788, Val Loss 0.6046, Val Acc 0.5038
# Epoch 2: Train Loss 0.2009, Train Acc 0.7986, Val Loss 0.1603, Val Acc 0.8295
# Epoch 3: Train Loss 0.1247, Train Acc 0.8832, Val Loss 0.1827, Val Acc 0.8079
# Epoch 4: Train Loss 0.0949, Train Acc 0.9074, Val Loss 1.1335, Val Acc 0.6819
# Epoch 5: Train Loss 0.0612, Train Acc 0.9440, Val Loss 0.0583, Val Acc 0.9580
# Epoch 6: Train Loss 0.0617, Train Acc 0.9411, Val Loss 0.5113, Val Acc 0.7735
# Epoch 7: Train Loss 0.0321, Train Acc 0.9672, Val Loss 0.0123, Val Acc 0.9898
# Epoch 8: Train Loss 0.0440, Train Acc 0.9574, Val Loss 0.0128, Val Acc 0.9860
# Epoch 9: Train Loss 0.0258, Train Acc 0.9784, Val Loss 0.1656, Val Acc 0.8842
# Epoch 10: Train Loss 0.0366, Train Acc 0.9675, Val Loss 0.0962, Val Acc 0.9148
# Early stopping at epoch 10
# Fold 1 Best Val Accuracy: 0.9898
#
# FOLD 2/5
# --------------------
# Epoch 1: Train Loss 0.5359, Train Acc 0.4687, Val Loss 0.2735, Val Acc 0.7036
# Epoch 2: Train Loss 0.1865, Train Acc 0.8136, Val Loss 0.0971, Val Acc 0.9135
# Epoch 3: Train Loss 0.1185, Train Acc 0.8871, Val Loss 0.1803, Val Acc 0.9020
# Epoch 4: Train Loss 0.0671, Train Acc 0.9373, Val Loss 0.0353, Val Acc 0.9707
# Epoch 5: Train Loss 0.0433, Train Acc 0.9583, Val Loss 0.2760, Val Acc 0.7570
# Epoch 6: Train Loss 0.0640, Train Acc 0.9376, Val Loss 0.1398, Val Acc 0.9033
# Epoch 7: Train Loss 0.0593, Train Acc 0.9456, Val Loss 0.0383, Val Acc 0.9580
# Early stopping at epoch 7
# Fold 2 Best Val Accuracy: 0.9707
#
# FOLD 3/5
# --------------------
# Epoch 1: Train Loss 0.5283, Train Acc 0.4871, Val Loss 0.2090, Val Acc 0.7824
# Epoch 2: Train Loss 0.1902, Train Acc 0.8161, Val Loss 0.1074, Val Acc 0.9033
# Epoch 3: Train Loss 0.1232, Train Acc 0.8810, Val Loss 0.1261, Val Acc 0.8753
# Epoch 4: Train Loss 0.0748, Train Acc 0.9259, Val Loss 0.2338, Val Acc 0.8677
# Epoch 5: Train Loss 0.0678, Train Acc 0.9421, Val Loss 0.0435, Val Acc 0.9529
# Epoch 6: Train Loss 0.0426, Train Acc 0.9596, Val Loss 0.0839, Val Acc 0.9275
# Epoch 7: Train Loss 0.0932, Train Acc 0.9157, Val Loss 3.3598, Val Acc 0.5102
# Epoch 8: Train Loss 0.0581, Train Acc 0.9402, Val Loss 0.0382, Val Acc 0.9656
# Epoch 9: Train Loss 0.0470, Train Acc 0.9570, Val Loss 0.0193, Val Acc 0.9873
# Epoch 10: Train Loss 0.0300, Train Acc 0.9768, Val Loss 0.0042, Val Acc 0.9975
# Epoch 11: Train Loss 0.0339, Train Acc 0.9644, Val Loss 0.0254, Val Acc 0.9796
# Epoch 12: Train Loss 0.0279, Train Acc 0.9765, Val Loss 0.2086, Val Acc 0.8868
# Epoch 13: Train Loss 0.0195, Train Acc 0.9860, Val Loss 0.0581, Val Acc 0.9580
# Early stopping at epoch 13
# Fold 3 Best Val Accuracy: 0.9975
#
# FOLD 4/5
# --------------------
# Epoch 1: Train Loss 0.5411, Train Acc 0.4811, Val Loss 0.2643, Val Acc 0.7354
# Epoch 2: Train Loss 0.2052, Train Acc 0.7929, Val Loss 0.2819, Val Acc 0.7290
# Epoch 3: Train Loss 0.1320, Train Acc 0.8699, Val Loss 0.7414, Val Acc 0.6654
# Epoch 4: Train Loss 0.0805, Train Acc 0.9192, Val Loss 0.1202, Val Acc 0.9109
# Epoch 5: Train Loss 0.0755, Train Acc 0.9255, Val Loss 0.0322, Val Acc 0.9656
# Epoch 6: Train Loss 0.0452, Train Acc 0.9500, Val Loss 0.0494, Val Acc 0.9491
# Epoch 7: Train Loss 0.0667, Train Acc 0.9402, Val Loss 0.0452, Val Acc 0.9555
# Epoch 8: Train Loss 0.0448, Train Acc 0.9596, Val Loss 0.0166, Val Acc 0.9835
# Epoch 9: Train Loss 0.0515, Train Acc 0.9583, Val Loss 0.0344, Val Acc 0.9631
# Epoch 10: Train Loss 0.0371, Train Acc 0.9669, Val Loss 0.0541, Val Acc 0.9491
# Epoch 11: Train Loss 0.0387, Train Acc 0.9647, Val Loss 0.1334, Val Acc 0.9033
# Early stopping at epoch 11
# Fold 4 Best Val Accuracy: 0.9835
#
# FOLD 5/5
# --------------------
# Epoch 1: Train Loss 0.4875, Train Acc 0.5296, Val Loss 0.2459, Val Acc 0.7032
# Epoch 2: Train Loss 0.1726, Train Acc 0.8321, Val Loss 0.1288, Val Acc 0.8688
# Epoch 3: Train Loss 0.1144, Train Acc 0.8912, Val Loss 2.6278, Val Acc 0.5083
# Epoch 4: Train Loss 0.0825, Train Acc 0.9176, Val Loss 0.0392, Val Acc 0.9567
# Epoch 5: Train Loss 0.0611, Train Acc 0.9453, Val Loss 0.0607, Val Acc 0.9478
# Epoch 6: Train Loss 0.0526, Train Acc 0.9526, Val Loss 1.0847, Val Acc 0.6790
# Epoch 7: Train Loss 0.0572, Train Acc 0.9485, Val Loss 0.0485, Val Acc 0.9490
# Early stopping at epoch 7
# Fold 5 Best Val Accuracy: 0.9567
#
# Mean Accuracy across 5 folds: 0.9796
# Best Accuracy observed: 0.9975
