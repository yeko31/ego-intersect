# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, Dataset
from torchvision import transforms, models
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import numpy as np
from PIL import Image
from copy import deepcopy
import matplotlib.pyplot as plt

# -------------------- Dataset --------------------
class MultiLabelDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        for subfolder in os.listdir(root_dir):
            sub_path = os.path.join(root_dir, subfolder)
            if not os.path.isdir(sub_path):
                continue
            label_vector = [int(x) for x in subfolder.split('_')]
            for fname in os.listdir(sub_path):
                if fname.lower().endswith(('.png','.jpg','.jpeg')):
                    self.images.append(os.path.join(sub_path, fname))
                    self.labels.append(label_vector)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = torch.tensor(self.labels[idx], dtype=torch.float)

        img = Image.open(img_path).convert("L")  # grayscale
        if self.transform:
            img = self.transform(img)

        # expand grayscale → 3 channels
        img = img.repeat(3, 1, 1)
        return img, label

# -------------------- Transforms --------------------
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

dataset = MultiLabelDataset(
    "", #Include data path 
    transform=transform
)

# -------------------- Model Loader --------------------
def get_model(pretrained="synthetic"):
    if pretrained == "imagenet":
        model = models.resnet50(weights="IMAGENET1K_V1")
    elif pretrained == "synthetic":
        # create same architecture
        model = models.resnet50(weights=None)
        model.fc = nn.Linear(model.fc.in_features, 3)
        ckpt_path = "" #Include check path 
        state_dict = torch.load(ckpt_path, map_location="cpu")
        model.load_state_dict(state_dict)

    # Freeze everything
    for param in model.parameters():
        param.requires_grad = True

    # Replace fc layer
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, 3)

    return model

# -------------------- KFold Cross-validation --------------------
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

results = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

best_acc = 0.0
best_model_wts = None
best_fold_history = None

# Early stopping
patience = 3
min_delta = 1e-4

for fold, (train_ids, val_ids) in enumerate(kf.split(np.arange(len(dataset)))):
    print(f"\nFOLD {fold+1}/{k_folds}")
    print("-"*20)

    train_sub = Subset(dataset, train_ids)
    val_sub   = Subset(dataset, val_ids)

    train_loader = DataLoader(train_sub, batch_size=16, shuffle=True)
    val_loader   = DataLoader(val_sub, batch_size=16)

    model = get_model(pretrained="synthetic")   # or "imagenet"
    model.to(device)

    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)

    best_val_acc = 0.0
    best_fold_wts = None
    epochs_no_improve = 0
    num_epochs = 30

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    for epoch in range(num_epochs):
        # ---- Training ----
        model.train()
        running_loss = 0.0
        y_true_train, y_pred_train = [], []
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            preds = (torch.sigmoid(out) > 0.5).int()
            y_true_train.extend(y.cpu().numpy())
            y_pred_train.extend(preds.cpu().numpy())

        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(y_true_train, y_pred_train)

        # ---- Validation ----
        model.eval()
        y_true, y_pred = [], []
        val_loss_total = 0.0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                val_loss_total += loss.item()
                preds = (torch.sigmoid(out) > 0.5).int()
                y_true.extend(y.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_acc = accuracy_score(y_true, y_pred)

        print(f"Epoch {epoch+1}: "
              f"Train Loss {train_loss:.4f}, Train Acc {train_acc:.4f}, "
              f"Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        # ---- Early stopping ----
        if val_acc - best_val_acc > min_delta:
            best_val_acc = val_acc
            best_fold_wts = deepcopy(model.state_dict())
            best_fold_history = deepcopy(history)
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    results.append(best_val_acc)
    print(f"Fold {fold+1} Best Val Accuracy: {best_val_acc:.4f}")

    if best_val_acc > best_acc:
        best_acc = best_val_acc
        best_model_wts = deepcopy(best_fold_wts)

print(f"\nMean Accuracy across {k_folds} folds: {np.mean(results):.4f}")
print(f"Best Accuracy observed: {best_acc:.4f}")

# -------------------- Save Best Model --------------------
save_path = "" #Include save path 
save_path_old = "" #Include save old path 
torch.save(best_model_wts, save_path)
torch.save(best_model_wts, save_path_old, _use_new_zipfile_serialization=False)

# -------------------- Plot Best Fold History --------------------
plt.figure(figsize=(10,6))
plt.plot(best_fold_history["train_loss"], label="Train Loss")
plt.plot(best_fold_history["val_loss"], label="Val Loss")
plt.plot(best_fold_history["train_acc"], label="Train Acc")
plt.plot(best_fold_history["val_acc"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Metric")
plt.title("Training/Validation Metrics (Best Fold) - ResNet50")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# FOLD 1/5
# --------------------
# Epoch 1: Train Loss 0.4048, Train Acc 0.5915, Val Loss 0.5505, Val Acc 0.6361
# Epoch 2: Train Loss 0.1844, Train Acc 0.8171, Val Loss 0.2263, Val Acc 0.8041
# Epoch 3: Train Loss 0.1032, Train Acc 0.9036, Val Loss 0.0685, Val Acc 0.9364
# Epoch 4: Train Loss 0.0823, Train Acc 0.9259, Val Loss 3.6726, Val Acc 0.4517
# Epoch 5: Train Loss 0.0753, Train Acc 0.9325, Val Loss 0.2430, Val Acc 0.8130
# Epoch 6: Train Loss 0.0554, Train Acc 0.9491, Val Loss 0.0281, Val Acc 0.9784
# Epoch 7: Train Loss 0.0350, Train Acc 0.9656, Val Loss 0.0243, Val Acc 0.9758
# Epoch 8: Train Loss 0.0505, Train Acc 0.9523, Val Loss 0.0218, Val Acc 0.9822
# Epoch 9: Train Loss 0.0398, Train Acc 0.9621, Val Loss 0.0090, Val Acc 0.9898
# Epoch 10: Train Loss 0.0304, Train Acc 0.9726, Val Loss 0.0054, Val Acc 0.9924
# Epoch 11: Train Loss 0.0332, Train Acc 0.9710, Val Loss 0.0309, Val Acc 0.9644
# Epoch 12: Train Loss 0.0348, Train Acc 0.9688, Val Loss 0.0007, Val Acc 1.0000
# Epoch 13: Train Loss 0.0196, Train Acc 0.9825, Val Loss 0.0499, Val Acc 0.9542
# Epoch 14: Train Loss 0.0425, Train Acc 0.9644, Val Loss 0.0417, Val Acc 0.9644
# Epoch 15: Train Loss 0.0171, Train Acc 0.9847, Val Loss 0.0724, Val Acc 0.9389
# Early stopping at epoch 15
# Fold 1 Best Val Accuracy: 1.0000
#
# FOLD 2/5
# --------------------
# Epoch 1: Train Loss 0.3975, Train Acc 0.5991, Val Loss 1.3686, Val Acc 0.2684
# Epoch 2: Train Loss 0.1677, Train Acc 0.8291, Val Loss 2.9606, Val Acc 0.2252
# Epoch 3: Train Loss 0.0966, Train Acc 0.9045, Val Loss 1.6804, Val Acc 0.5445
# Epoch 4: Train Loss 0.0977, Train Acc 0.9084, Val Loss 0.0552, Val Acc 0.9415
# Epoch 5: Train Loss 0.0582, Train Acc 0.9430, Val Loss 0.0373, Val Acc 0.9656
# Epoch 6: Train Loss 0.0364, Train Acc 0.9701, Val Loss 0.9488, Val Acc 0.6285
# Epoch 7: Train Loss 0.0711, Train Acc 0.9319, Val Loss 0.0322, Val Acc 0.9707
# Epoch 8: Train Loss 0.0372, Train Acc 0.9609, Val Loss 0.0681, Val Acc 0.9377
# Epoch 9: Train Loss 0.0365, Train Acc 0.9656, Val Loss 0.1948, Val Acc 0.8193
# Epoch 10: Train Loss 0.0222, Train Acc 0.9780, Val Loss 0.0069, Val Acc 0.9962
# Epoch 11: Train Loss 0.0337, Train Acc 0.9698, Val Loss 0.2929, Val Acc 0.8257
# Epoch 12: Train Loss 0.0605, Train Acc 0.9440, Val Loss 0.0293, Val Acc 0.9746
# Epoch 13: Train Loss 0.0156, Train Acc 0.9844, Val Loss 0.0021, Val Acc 0.9987
# Epoch 14: Train Loss 0.0133, Train Acc 0.9866, Val Loss 0.0029, Val Acc 0.9949
# Epoch 15: Train Loss 0.0225, Train Acc 0.9803, Val Loss 0.0025, Val Acc 0.9975
# Epoch 16: Train Loss 0.0144, Train Acc 0.9847, Val Loss 0.0016, Val Acc 0.9987
# Early stopping at epoch 16
# Fold 2 Best Val Accuracy: 0.9987
#
# FOLD 3/5
# --------------------
# Epoch 1: Train Loss 0.3917, Train Acc 0.6074, Val Loss 0.2570, Val Acc 0.7506
# Epoch 2: Train Loss 0.1625, Train Acc 0.8409, Val Loss 0.0799, Val Acc 0.9389
# Epoch 3: Train Loss 0.0861, Train Acc 0.9166, Val Loss 4.7580, Val Acc 0.4198
# Epoch 4: Train Loss 0.0943, Train Acc 0.9138, Val Loss 0.3297, Val Acc 0.7570
# Epoch 5: Train Loss 0.0461, Train Acc 0.9564, Val Loss 0.0207, Val Acc 0.9796
# Epoch 6: Train Loss 0.0554, Train Acc 0.9446, Val Loss 0.0970, Val Acc 0.9148
# Epoch 7: Train Loss 0.0370, Train Acc 0.9672, Val Loss 2.0466, Val Acc 0.5229
# Epoch 8: Train Loss 0.0495, Train Acc 0.9535, Val Loss 0.0840, Val Acc 0.9288
# Early stopping at epoch 8
# Fold 3 Best Val Accuracy: 0.9796
#
# FOLD 4/5
# --------------------
# Epoch 1: Train Loss 0.3921, Train Acc 0.6061, Val Loss 0.2257, Val Acc 0.7748
# Epoch 2: Train Loss 0.1702, Train Acc 0.8342, Val Loss 0.2877, Val Acc 0.8257
# Epoch 3: Train Loss 0.1064, Train Acc 0.8963, Val Loss 0.3337, Val Acc 0.8193
# Epoch 4: Train Loss 0.0793, Train Acc 0.9262, Val Loss 0.2140, Val Acc 0.8321
# Epoch 5: Train Loss 0.0433, Train Acc 0.9615, Val Loss 0.0307, Val Acc 0.9707
# Epoch 6: Train Loss 0.0706, Train Acc 0.9341, Val Loss 0.0355, Val Acc 0.9707
# Epoch 7: Train Loss 0.0382, Train Acc 0.9647, Val Loss 0.0402, Val Acc 0.9580
# Epoch 8: Train Loss 0.0476, Train Acc 0.9593, Val Loss 0.1355, Val Acc 0.8931
# Early stopping at epoch 8
# Fold 4 Best Val Accuracy: 0.9707
#
# FOLD 5/5
# --------------------
# Epoch 1: Train Loss 0.3650, Train Acc 0.6428, Val Loss 0.5938, Val Acc 0.5873
# Epoch 2: Train Loss 0.1521, Train Acc 0.8489, Val Loss 0.2803, Val Acc 0.7554
# Epoch 3: Train Loss 0.1105, Train Acc 0.8995, Val Loss 0.0487, Val Acc 0.9516
# Epoch 4: Train Loss 0.0901, Train Acc 0.9128, Val Loss 0.1124, Val Acc 0.8904
# Epoch 5: Train Loss 0.0401, Train Acc 0.9558, Val Loss 0.0240, Val Acc 0.9720
# Epoch 6: Train Loss 0.0350, Train Acc 0.9618, Val Loss 0.0451, Val Acc 0.9567
# Epoch 7: Train Loss 0.0427, Train Acc 0.9596, Val Loss 0.0149, Val Acc 0.9911
# Epoch 8: Train Loss 0.0254, Train Acc 0.9742, Val Loss 0.0389, Val Acc 0.9580
# Epoch 9: Train Loss 0.0302, Train Acc 0.9723, Val Loss 0.0070, Val Acc 0.9949
# Epoch 10: Train Loss 0.0357, Train Acc 0.9641, Val Loss 0.0306, Val Acc 0.9643
# Epoch 11: Train Loss 0.0325, Train Acc 0.9704, Val Loss 0.1081, Val Acc 0.9287
# Epoch 12: Train Loss 0.0255, Train Acc 0.9761, Val Loss 0.0262, Val Acc 0.9720
# Early stopping at epoch 12
# Fold 5 Best Val Accuracy: 0.9949
#
# Mean Accuracy across 5 folds: 0.9888
# Best Accuracy observed: 1.0000

# %%
import re
import matplotlib.pyplot as plt

# --- Path to your log file ---
log_path = ""

# --- Read file ---
with open(log_path, "r") as f:
    lines = f.readlines()

# --- Prepare storage ---
epochs = []
train_loss, val_loss = [], []
train_acc, val_acc = [], []

# --- Parse each line ---
for line in lines:
    match = re.search(
        r"Epoch (\d+): Train Loss ([\d.]+), Train Acc ([\d.]+), Val Loss ([\d.]+), Val Acc ([\d.]+)",
        line.strip()
    )
    if match:
        e, tl, ta, vl, va = match.groups()
        epochs.append(int(e))
        train_loss.append(float(tl))
        train_acc.append(float(ta))
        val_loss.append(float(vl))
        val_acc.append(float(va))

# --- Plot ---
plt.figure(figsize=(10,6))
plt.plot(epochs, train_loss, label="Train Loss", linestyle="--", marker="o")
plt.plot(epochs, val_loss, label="Val Loss", linestyle="--", marker="s")
plt.plot(epochs, train_acc, label="Train Acc", linestyle="-", marker="o")
plt.plot(epochs, val_acc, label="Val Acc", linestyle="-", marker="s")

plt.title("Training and Validation Metrics per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
